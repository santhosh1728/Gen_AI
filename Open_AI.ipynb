# %%
import openai

# %%
pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import openai

# %% [raw]
# By using OpenAI API we can unlock the advance functionalities and we can enhane the intelligence and performance of our application

# %% [markdown]
# ## Generating OpenAI API key

# %%
mykey = "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"
# mykey = "sk-dAMn0f4t0xStih3twZ4T3BlbkFJYwyYrDMNh16Dt79LP8xR"

# %%
openai.api_key=mykey

# %%
openai.models.list()
# Out:
# SyncPage[Model](data=[Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-16k-0613', created=1685474247, object='model', owned_by='openai'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0301', created=1677649963, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0613', created=1686587434, 
# ...

# %%
all_models = openai.models.list()

# %%
import pandas as pd

pd.DataFrame(list(all_models),columns=["id","created","object","owned_by"])
# Out:
# C:\Users\santh\anaconda3\anaconda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                    id                created           object  \
# 0            (id, gpt-3.5-turbo-1106)  (created, 1698959748)  (object, model)
# 1                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 2        (id, gpt-3.5-turbo-16k-0613)  (created, 1685474247)  (object, model)
# 3                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 4        (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 5                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 6                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 7                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.DataFrame(list(all_models),)
# Out:
#                                     0                      1                2  \
# 0            (id, gpt-3.5-turbo-1106)  (created, 1698959748)  (object, model)
# 1                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 2        (id, gpt-3.5-turbo-16k-0613)  (created, 1685474247)  (object, model)
# 3                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 4        (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 5                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 6                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 7                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 8                 (id, gpt-3.5-turbo)  (created, 1677610602)  (object, model)
# 9            (id, gpt-3.5-turbo-0125)  (created, 1706048358)  (object, model)
# 10           (id, gpt-3.5-turbo-0301)  (created, 1677649963)  (object, model)
# ...

# %%
# install from PyPI
pip install openai
# Out:
#   Cell In[12], line 2
#     pip install openai
#         ^
# SyntaxError: invalid syntax

# %%
pip install openai

# %%
from openai import OpenAI
client = OpenAI(api_key=mykey)

# %%
response = client.chat.completions.create(
model = 'gpt-3.5-turbo',
messages = [
    {
        "role" : "user",
        "content" : "how i can learn GENerative AI"
        
    
    },
],
   #max_tokens = 150,
    #n=3


)

# %% [raw]
# response
# response.choices[0],message.content

# %% [markdown]
# # different parameters inside the methods
#
# model = "
#
# prompt = input prompt
#
# max_tokens = in how many number of tokens you want result
# tempereature= for getting some creative output
# n = number of output
#
#
# "

# %% [raw]
# import os
# from openai import OpenAI
#
# client = OpenAI(
#     # This is the default and can be omitted
#     api_key=os.environ.get("OPENAI_API_KEY"),
# )
#
# chat_completion = client.chat.completions.create(
#     messages=[
#         {
#             "role": "user",
#             "content": "Say this is a test",
#         }
#     ],
#     model="gpt-3.5-turbo",
# )
